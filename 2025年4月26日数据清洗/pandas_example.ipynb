# %%
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('./data/demo_01.xlsx')

# %%
#!pip install openpyxl
# df = pd.read_excel('./data/demo_01.xlsx', engine = 'openxl')
# ./当前目录
# ..上级目录
# ../../上上级目录
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.head() #传5行数据
# df.head(数字) 传数字行数据

# %%
# pd.set_option('compute.use_numba')设置计算引擎
# pd.get_option('compute.use_numba')获取指定选项的设置情况

# %%
#创建Series对象
s1 = pd.Series([87, 34, 64])
s1
# Out:
# 0    87
# 1    34
# 2    64
# dtype: int64

# %%
#数字索引
s2 = pd.Series([98, 78, 56], index = [10, 20, 30])
s2
# Out:
# 10    98
# 20    78
# 30    56
# dtype: int64

# %%
#字符串索引
s3 = pd.Series([54, 57, 93], index=['田乐', '陈靓丽', '王雪梨'])
s3
# Out:
# 田乐     54
# 陈靓丽    57
# 王雪梨    93
# dtype: int64

# %%
#Series的索引操作
s4 = pd.Series([89,76,59,63,79], index=['田乐', '陈靓丽', '王雪梨','王晓辉','渣渣辉'])
#通过索引号取值
#s4[0]
#通过索引名取值
#s4['田乐']
#通过多个索引名取值
#s4[['陈靓丽','田乐']]
#通过索引名切片取值
#s4['田乐':'王雪梨']
#索引号取值
#s4[1:4]
#获取Series的所有索引
#s4.index
#获取Series的所有值
#s4.values
#判断Series是否包含空值
#s4.hasnans
# Out:
# np.int64(89)
